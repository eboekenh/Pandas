# %% [markdown]
# <a href="https://colab.research.google.com/github/eboekenh/Pandas/blob/main/Ex_1_test_scores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
help(np.random)

# %%
s=pd.Series(np.random.randint(70,101,10))
s
# Out:
# 0     98
# 1     99
# 2     91
# 3     98
# 4     93
# 5     83
# 6     87
# 7    100
# 8     88
# 9     73
# dtype: int64

# %%
months = ["September", "October", "November", "December", "January", "February", "March", "April", "May", "June"]
print(months)
# Out:
# ['September', 'October', 'November', 'December', 'January', 'February', 'March', 'April', 'May', 'June']

# %%
notes = pd.Series(data=s.values, index=months)
notes
# Out:
# September     98
# October       99
# November      91
# December      98
# January       93
# February      83
# March         87
# April        100
# May           88
# June          73
# dtype: int64

# %%
s.mean()
# Out:
# np.float64(91.0)

# %%
s[:6].mean()
# Out:
# np.float64(93.66666666666667)

# %%
s[-6:].mean()
# Out:
# np.float64(87.33333333333333)
